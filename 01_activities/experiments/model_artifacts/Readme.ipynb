# %% [markdown]
# We created 2 models - Diabetes risk model and feature_columns model to predict if someone has high, medium or low risk for diabetes
# We are planning to host the UI ( app.py) and the diabetes_risk_model.pkl and features_columsn.pkl on streamlit for public access from the internet.
#
# Here is the URL - https://diabetes-risk-app-c8xecfdez8qtgej3wnwqy2.streamlit.app/
#
# Note: this is our very first version which we will improve and optimize.
